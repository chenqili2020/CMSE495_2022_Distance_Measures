# %% [markdown]
# # Report on the Projects Distance Matrix for CMSE495
# ### Team Name: Kellogg's

# %% [markdown]
# ## Abstract
# We get to see who thought their project was similar to ours (hint no one did) because we have to use R 😢

# %% [markdown]
# ## Data input
# Import the csv files.

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
data = pd.read_csv("2022_Project_distance_Matrix.csv")
data
# Out:
#     ARFL  Argonne  Boeing  Delta Dental  Ford  Hope Village  Kellogg's  \
# 0      7        4       9             8     3             0          6
# 1      0        1       3             2     4             8          6
# 2      3        2       1             6     0             8          5
# 3      8        7       3             9     4             5          0
# 4      0        2       1             8     7             3          9
# 5      3        2       0             6     9             7          8
# 6      3        4       2             9     8             6          0
# 7      1        2       5             3     0             6          9
# 8      6        1       0             5     2             9          4
# 9      3        1       2             6     0             8          9
# 10     1        7       8             0     9             6          5
# 11     5        4       3             6     0             7          2
# ...

# %% [markdown]
# ## Data Modeling
# We created a distance matrix based on the csv file.

# %%
matri = pd.DataFrame([data[data[i]==0].mean().values.tolist() for i in data.columns])
matri.columns = data.columns
matri.index = data.columns
matri = matri.round(2)
matri
# Out:
#               ARFL  Argonne  Boeing  Delta Dental  Ford  Hope Village  \
# ARFL          0.00     3.00    3.00          5.20  4.00          6.20
# Argonne       2.67     0.00    1.67          3.33  6.67          5.33
# Boeing        3.20     2.60    0.00          6.20  4.60          8.00
# Delta Dental  1.67     7.33    6.00          0.00  6.67          5.33
# Ford          2.50     2.50    2.83          5.67  0.00          7.67
# Hope Village  6.20     5.40    7.20          6.40  7.20          0.00
# Kellogg's     4.33     5.67    4.33          8.33  7.00          5.33
# Neogen        3.67     4.00    3.33          7.00  5.67          5.33
# Old Nation    6.00     5.25    7.50          6.25  6.25          1.25
# Qside         3.50     3.50    6.00          7.00  8.00          1.50
#
#               Kellogg's  Neogen  Old Nation  Qside
# ARFL               6.60    4.00        5.60   7.40
# Argonne            8.00    6.00        5.00   6.33
# ...

# %%
matri.describe()
# Out:
#             ARFL   Argonne     Boeing  Delta Dental     Ford  Hope Village  \
# count  10.000000  10.00000  10.000000     10.000000  10.0000     10.000000
# mean    3.374000   3.92500   4.186000      5.538000   5.6060      4.594000
# std     1.870141   2.07643   2.460796      2.343662   2.3074      2.742032
# min     0.000000   0.00000   0.000000      0.000000   0.0000      0.000000
# 25%     2.542500   2.70000   2.872500      5.317500   4.8675      2.457500
# 50%     3.350000   3.75000   3.830000      6.225000   6.4600      5.330000
# 75%     4.165000   5.36250   6.000000      6.850000   6.9175      5.982500
# max     6.200000   7.33000   7.500000      8.330000   8.0000      8.000000
#
#        Kellogg's     Neogen  Old Nation      Qside
# count  10.000000  10.000000   10.000000  10.000000
# mean    5.913000   4.075000    3.740000   4.048000
# std     2.314712   2.084441    2.147138   2.724093
# min     0.000000   0.000000    0.000000   0.000000
# ...

# %% [markdown]
# ## Data Visualization
# This is the heapmap of the distance matrix. Dark means the similar group, Bright means they think they are totally different project.
#
# It read row by row,
# for example, the first row is the ARFL's opinion on other teams' project.

# %%
import numpy as np
import seaborn as sns
sns.set(rc = {'figure.figsize':(10,8)})
ax = sns.heatmap(matri)

# %%
sns.set(rc = {'figure.figsize':(8,6)})
ax2 = sns.clustermap(matri)

# %% [markdown]
# ## Conclusion
#
# We found out that people don't think our project is similar to otheirs :( , poor kellogg team
#
# ![rip](https://c.tenor.com/dWv85aZvmsAAAAAM/justin-jefferson.gif)
# ![pepe](https://www.pikpng.com/pngl/m/138-1381728_goldman-sachs-trump-memes-rare-pepe-honey-smacks.png)
